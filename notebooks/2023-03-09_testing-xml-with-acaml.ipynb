# %% [markdown]
# # Testing Parsing XML Files With BeautifulSoup, Specifically acq.macaml

# %% [markdown]
# ## Setting up the Environment

# %%
from pathlib import Path

from bs4 import BeautifulSoup as bs

# %%
p = Path('/Users/jonathan/0_jono_data/2023-03-01_15-22-02_ACETONE_VOID-VOL-MEASUREMENT.sequence/ACETONE0002.D/acq.macaml')

# %%
def read_single_signal_xml(path):
    if path.is_file():
        with path.open() as f:

            file = f.read()

            soup = bs(file, 'xml')

            single_signal_dict = {}


        for section in soup.Content.Section:
            if "Signal" in section.text:
                for row in section.Table.find_all('Row'):
                    for parameter in row.find_all('Parameter'):
                        if "Signals_Signal_ID" in parameter.find('ID'):

                            signal_ID = parameter.Value.text

                        if "Signals_Signal_Wavelength" in parameter.find('ID'):
                            signal_wavelength = f"{parameter.Value.text} {parameter.Unit.text}"
                        
                        if "Signals_Signal_Bandwidth" in parameter.find("ID"):
                            signal_bandwidth = f"{parameter.Value.text} {parameter.Unit.text}"

                    single_signal_dict[signal_ID] = {"wavelength" : signal_wavelength,
                         "bandwidth" : signal_bandwidth}

        # Each row has multiple parameters, each which has its own Name, ID, Unit, and Value.
        # 
        # The first parameter asks whether to 'use' the signal, I guess for the trace?
        # 
        # The second paramter contains the designation of the signal from A to H (?) as Value = 'Signal X' where X is the letter, 
        # the third parameter contains the wavelength of the signal, where Unit is 'nm' and 'Value' is the Scalar value of the unit.
        #
        # The fourth parameter contains the signal bandwidth, in the same form as the third parameter.
        # 
        # The fifth parameter covers the use of a reference signal, containing a boolean "Yes" or "No".
    
    else:
        print("bad input")
    return single_signal_dict

# %%
for file in Path("/Users/jonathan/0_jono_data").rglob("*.D/*acq.macaml"):
    print(file.parent.name)
    print(read_single_signal_xml(file))
# Out:
# 2023-02-15_COFFEE_COLUMN_CHECK.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-09_14-59-17_NC1.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_WINE_TEST_GRAD_2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_COFFEE-TEST_2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-23_2021-DEBORTOLI-CABERNET-MERLOT_AVANTOR.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-09_14-30-37_Z3.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_KOERNER-NELLUCIO-02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2022-08-02_CAFFEINE_STANDARD_50PPM.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 2023-02-08_16-05-13_Z3.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-01_Z3_SECOND_RUN_OF_THE_DAY.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_PHENOL_TEST.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_WINE_TEST_GRAD_1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_COFFEE-TEST-1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-14_0052_TESTING_COLUMN_FOR_SAMPLE_DEG.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_WINE_TEST_GRAD_5.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '300.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '320.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '320.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-01_Z3_FOURTH_RUN_OF_THE_DAY.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-01_Z3_THIRD_RUN_OF_THE_DAY.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-07_14-10-47_Z3-NO-FORMIC-ACID-1.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2022-08-01_CAFFEINE_MOCCONA CLASSIC INSTANT.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 2023-02-07_11-22-37_BLANK-4.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_STONEY-RISE-PN_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_2021-DEBORTOLI-CABERNET-MERLOT_AVANTOR.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-01_Z3_FIRST_RUN_OF_DAY.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_HEY-MALBEC_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_LOR-RISTRETTO.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2022-08-01_CAFFEINE_ISOCRATIC_LOR ESPRESSO RISTRETTO.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 2023-02-07_17-08-25_0051.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-09_13-49-55_ESPRESSO.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-23_LOR-RISTRETTO.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-07_18-30-07_Z3-ID-NM-ABS-MAX.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_CRAWFORD-CAB_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-16_0291.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-16_0232.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-07_12-01-43_Z3-1.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-01-23_COFFEE-TEST_3.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-15_COFFEE_COLUMN_CHECK_2.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_STONEY-RISE-PN_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_STONEY-RISE-PN_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 20220801_CAFFEINE_10PPM1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 005-0501.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 001-0101.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 003-0301.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 004-0401.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 006-0601.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 002-0201.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 005-0501.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 015-1401.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 007-0701.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 017-1601.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 011-1001.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 001-0101.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 013-1201.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 003-0301.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 008-0801.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 004-0401.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 014-1301.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 006-0601.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 016-1501.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 009-0901.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 012-1101.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 002-0201.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '252.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_STONEY-RISE-PN_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_STONEY-RISE-PN_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 20220801_CAFFEINE_75PPM1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAP_WOOLIES_MED_ROAST.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_INSTANT_WOOLIES_MED_ROAST.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_10PPM1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_50PPM_ISO1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_75PPM2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_INSTANT_VITTORIA_CLASSIC.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_INSTANT_NESCAFE_GOLD.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_10PPM2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_INSTANT_MOCCONA_CLASSIC.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_50PPM_ISO2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_25PPM2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_50PPM_GRADIENT.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# WATER2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_100PPM2.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_INSTANT_NESCAFE_BLEND_43.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAP_LOR_RISTRETTO.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAP_NESTLE_AFRICAS.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_100PPM1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# WATER1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# 20220801_CAFFEINE_25PPM1.D
# {'Signal A': {'wavelength': '254.0 nm', 'bandwidth': '2.0 nm'}, 'Signal B': {'wavelength': '450.0 nm', 'bandwidth': '2.0 nm'}, 'Signal C': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal D': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal E': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal F': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal G': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}, 'Signal H': {'wavelength': '280.0 nm', 'bandwidth': '2.0 nm'}}
# ACETONE0002.D
# {'Signal A': {'wavelength': '195.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '279.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# ACETONE0006.D
# {'Signal A': {'wavelength': '195.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '279.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# ACETONE0001.D
# {'Signal A': {'wavelength': '195.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '279.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# ACETONE0005.D
# {'Signal A': {'wavelength': '195.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '279.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# ACETONE0004.D
# {'Signal A': {'wavelength': '195.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '279.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# ACETONE0003.D
# {'Signal A': {'wavelength': '195.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '279.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 007-0301.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 009-0501.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 019-1101.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 005-0101.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 015-0701.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 029-1601.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 016-0801.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 027-1401.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 008-0401.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 030-1701.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 020-1201.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 006-0201.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 018-1001.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 010-0601.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 026-1301.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 028-1501.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 017-0901.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2023-02-22_STONEY-RISE-PN_02-21.D
# {'Signal A': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '244.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '248.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '254.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '256.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# Z2.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# Z1.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 1.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
# 2.D
# {'Signal A': {'wavelength': '200.0 nm', 'bandwidth': '4.0 nm'}, 'Signal B': {'wavelength': '210.0 nm', 'bandwidth': '4.0 nm'}, 'Signal C': {'wavelength': '220.0 nm', 'bandwidth': '4.0 nm'}, 'Signal D': {'wavelength': '230.0 nm', 'bandwidth': '4.0 nm'}, 'Signal E': {'wavelength': '240.0 nm', 'bandwidth': '4.0 nm'}, 'Signal F': {'wavelength': '250.0 nm', 'bandwidth': '4.0 nm'}, 'Signal G': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}, 'Signal H': {'wavelength': '260.0 nm', 'bandwidth': '4.0 nm'}}
