# %%
from pathlib import Path

p = Path('../002_0_jono_data/single_runs')

for x in p.iterdir():
    for y in x.iterdir():
        print(y)
# Out:
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/sample.acaml
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/ACQRES.REG
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/acq.txt
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/LCDIAG.REG
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/RUN.LOG
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/SINGLE.B
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/DAD1A.ch
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/DA.M
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/acq.macaml
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/SAMPLE.XML
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/da.macaml
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/CSlbk.ini
# ../002_0_jono_data/single_runs/20230123_COFFEE_TEST_1.D/SAMPLE.XML.bak
# ../002_0_jono_data/single_runs/20230123_WINE_TEST_GRAD_4.D/sample.acaml
# ...
